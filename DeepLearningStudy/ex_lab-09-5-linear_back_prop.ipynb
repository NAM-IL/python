# %% [markdown]
# # [ ex_lab-09-5-linear_back_prop ]
#
# ><p>출처: <a href="http://hunkim.github.io/ml/" title="모두를 위한 머신러닝과 딥러닝의 강의" target="blank">모두를 위한 머신러닝과 딥러닝의 강의</a></p>
#
#
# ><p>참고: <br/>
#   > <a href="http://blog.aloni.org/posts/backprop-with-tensorflow/" title="Back propagation with TensorFlow - Dan Aloni's blog" target="_blank">Back propagation with TensorFlow - Dan Aloni's blog</a><br/>
#
#  >  <a href="https://medium.com/@karpathy/yes-you-should-understand-backprop-e2f06eab496b#.b3rvzhx89" title="Yes you should understand backprop - Andrej Karpathy" target="_blank">Yes you should understand backprop - Andrej Karpathy</a>
# </p>
# >[Yes you should understand backprop - Andrej Karpathy](https://medium.com/@karpathy/yes-you-should-understand-backprop-e2f06eab496b#.b3rvzhx89  title="Yes you should understand backprop - Andrej Karpathy" target="_blank")

# %%
# http://blog.aloni.org/posts/backprop-with-tensorflow/
# https://medium.com/@karpathy/yes-you-should-understand-backprop-e2f06eab496b#.b3rvzhx89
# WIP
import os
# silence INFO logs set it to 1
# filter out WARNING set it to 2 
# silence ERROR logs (not recommended) set it to 3
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf

print('tensorflow version: {0}'.format(tf.__version__))
# Out:
# tensorflow version: 1.2.0

# %% [markdown]
# # reproducibility

# %%
tf.set_random_seed(777)  # reproducibility

# %% [markdown]
# # tf Graph Input

# %%
# tf Graph Input
x_data = [[1.],
          [2.],
          [3.]]
y_data = [[1.],
          [2.],
          [3.]]

# %% [markdown]
# # placeholders for a tensor that will be always fed.

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 1])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %% [markdown]
# # Set wrong model weights

# %%
# Set wrong model weights
W = tf.Variable(tf.truncated_normal([1, 1]))
b = tf.Variable(5.)

# %% [markdown]
# # Forward propagation

# %%
# Forward prop
hypothesis = tf.matmul(X, W) + b

# %% [markdown]
# # diff

# %%
# diff
assert hypothesis.shape.as_list() == Y.shape.as_list()
diff = (hypothesis - Y)

# %% [markdown]
# # Back propagation (chain rule)

# %%
# Back prop (chain rule)
d_l1 = diff
d_b = d_l1
d_w = tf.matmul(tf.transpose(X), d_l1)

print(X, W, d_l1, d_w)
# Out:
# Tensor("Placeholder_6:0", shape=(?, 1), dtype=float32) <tf.Variable 'Variable_6:0' shape=(1, 1) dtype=float32_ref> Tensor("sub_12:0", shape=(?, 1), dtype=float32) Tensor("MatMul_7:0", shape=(1, 1), dtype=float32)

# %% [markdown]
# # Updating network using gradients

# %%
# Updating network using gradients
learning_rate = 0.1
step = [
    tf.assign(W, W - learning_rate * d_w),
    tf.assign(b, b - learning_rate * tf.reduce_mean(d_b)),
]

# %% [markdown]
# # 7. Running and testing the training process

# %%
# 7. Running and testing the training process
RMSE = tf.reduce_mean(tf.square((Y - hypothesis)))

sess = tf.InteractiveSession()
init = tf.global_variables_initializer()
sess.run(init)

for i in range(1000):
    print(i, sess.run([step, RMSE], feed_dict={X: x_data, Y: y_data}))

print(sess.run(hypothesis, feed_dict={X: x_data}))
# Out:
# 0 [[array([[-1.69601607]], dtype=float32), 4.6519918], 12.495984]
# 1 [[array([[-0.7127887]], dtype=float32), 4.725996], 5.3933277]
# 2 [[array([[-1.15048218]], dtype=float32), 4.5959539], 3.6468523]
# 3 [[array([[-0.89737952]], dtype=float32), 4.5664549], 3.170068]
# 4 [[array([[-0.98092109]], dtype=float32), 4.4892855], 2.9955478]
# 5 [[array([[-0.90120286]], dtype=float32), 4.4365411], 2.8942289]
# 6 [[array([[-0.90144348]], dtype=float32), 4.3731275], 2.8118424]
# 7 [[array([[-0.86329907]], dtype=float32), 4.3161035], 2.7354989]
# 8 [[array([[-0.84434241]], dtype=float32), 4.257153], 2.6621053]
# 9 [[array([[-0.81655484]], dtype=float32), 4.2003064], 2.5908887]
# 10 [[array([[-0.79356194]], dtype=float32), 4.1435866], 2.5216265]
# 11 [[array([[-0.76872718]], dtype=float32), 4.0879402], 2.4542272]
# 12 [[array([[-0.74527329]], dtype=float32), 4.0328918], 2.3886316]
# 13 [[array([[-0.72162575]], dtype=float32), 3.9786572], 2.3247907]
# ...
